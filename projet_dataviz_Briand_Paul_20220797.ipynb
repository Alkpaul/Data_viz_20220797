# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

df = pd.read_csv('/content/2012-2022-balances-des-comptes-de-letat.csv', encoding='latin1', sep=';')
df.head()
# Out:
#                       Postes               Sous-postes  \
# 0   Produits régaliens nets       Impôt sur le revenu
# 1   Produits régaliens nets       Impôt sur le revenu
# 2   Produits régaliens nets    Impôt sur les sociétés
# 3   Produits régaliens nets    Impôt sur les sociétés
# 4   Produits régaliens nets    Impôt sur les sociétés
#
#        Indicateurs de synthèse Indicateurs de détail      Compte  \
# 0     R001_Impôt sur le revenu                   NaN  7711000000
# 1     R001_Impôt sur le revenu                   NaN  7711000000
# 2  R002_Impôt sur les sociétés                   NaN  7712000000
# 3  R002_Impôt sur les sociétés                   NaN  7712000000
# 4  R002_Impôt sur les sociétés                   NaN  7712000000
#
#   Nature Budgétaire Programme              Libellé Ministère  \
# 0            110102      0156  Économie, finances et relance
# 1            110104       RBG                            NaN
# 2               NaN       RBG                            NaN
# 3            130105       RBG                            NaN
# 4            130106      0200  Économie, finances et relance
#
#     Balance Sortie 2022    Balance Sortie 2021    Balance Sortie 2020   \
# 0                 -                      -                      -
# 1   -5 762 963 841,71      -4 864 092 885,61      -3 590 716 672,16
# 2     -352 509 415,00                    -                      -
# 3  -16 228 747 755,31     -11 515 629 624,35     -11 976 229 407,93
# 4                 -                      -                      -
#
#    Balance Sortie 2019   Balance Sortie 2018   Balance Sortie 2017   \
# 0                -                     -                     -
# 1  -3 484 317 723,45     -7 079 016 491,88     -3 957 557 176,66
# 2                -                     -                     -
# 3  -7 561 545 495,89     -8 008 174 469,66     -7 148 930 098,63
# 4                -                     -                     -
#
#    Balance Sortie 2016   Balance Sortie 2015   Balance Sortie 2014   \
# 0                -                     -                     -
# 1  -4 001 684 125,72     -4 286 556 173,03       -966 477 169,56
# 2                -                     -                     -
# 3  -6 529 464 229,24     -6 093 777 596,66     -6 109 826 081,66
# 4                -                     -                     -
#
#    Balance Sortie 2013   Balance Sortie 2012
# 0                -              -13 075,00
# 1  -3 225 776 389,83                   -
# 2      62 691 130,44     -5 030 904 435,04
# 3  -8 203 336 316,67     -8 661 000 718,10
# 4                -                     -

# %%
df.tail()
# Out:
#                          Postes          Sous-postes  \
# 99222   Dettes non financières    Dettes à ventiler
# 99223   Dettes non financières    Dettes à ventiler
# 99224   Dettes non financières    Dettes à ventiler
# 99225   Dettes non financières    Dettes à ventiler
# 99226   Dettes non financières    Dettes à ventiler
#
#                                  Indicateurs de synthèse  \
# 99222  S905_Dettes non financières à ventiler manuell...
# 99223  S905_Dettes non financières à ventiler manuell...
# 99224  S905_Dettes non financières à ventiler manuell...
# 99225  S905_Dettes non financières à ventiler manuell...
# 99226  S905_Dettes non financières à ventiler manuell...
#
#       Indicateurs de détail      Compte Nature Budgétaire Programme  \
# 99222                   NaN  4081000000               NaN      0335
# 99223                   NaN  4081000000           TECH_BE      0152
# 99224                   NaN  4081000000           TECH_BE      0206
# 99225                   NaN  4081000000           TECH_BE      0218
# 99226                   NaN  4081000000           TECH_BE      0333
#
#                    Libellé Ministère  Balance Sortie 2022   \
# 99222                        Justice                -
# 99223                      Intérieur                -
# 99224    Agriculture et alimentation                -
# 99225  Économie, finances et relance                -
# 99226                            NaN                -
#
#        Balance Sortie 2021   Balance Sortie 2020   Balance Sortie 2019   \
# 99222                -                     -                     -
# 99223                -                     -                     -
# 99224                -                     -                     -
# 99225                -                     -                     -
# 99226                -                     -                     -
#
#        Balance Sortie 2018   Balance Sortie 2017   Balance Sortie 2016   \
# 99222                -                     -                     -
# 99223                -                     -                     -
# 99224                -                     -                     -
# 99225                -                     -                     -
# 99226                -                     -                     -
#
#        Balance Sortie 2015   Balance Sortie 2014   Balance Sortie 2013   \
# 99222                -              -79 655,16            -18 469,49
# 99223                -                     -                     -
# 99224                -                     -                     -
# 99225                -                     -                     -
# 99226                -                     -                     -
#
#        Balance Sortie 2012
# 99222                -
# 99223                -
# 99224                -
# 99225                -
# 99226                -

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99227 entries, 0 to 99226
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Postes                   99227 non-null  object
#  1   Sous-postes              99227 non-null  object
#  2   Indicateurs de synthèse  99227 non-null  object
#  3   Indicateurs de détail    83417 non-null  object
#  4   Compte                   99227 non-null  int64
#  5   Nature Budgétaire        74102 non-null  object
#  6   Programme                95960 non-null  object
#  7   Libellé Ministère        80057 non-null  object
#  8    Balance Sortie 2022     99227 non-null  object
#  9    Balance Sortie 2021     99227 non-null  object
#  10   Balance Sortie 2020     99227 non-null  object
#  11   Balance Sortie 2019     99227 non-null  object
#  12   Balance Sortie 2018     99227 non-null  object
#  13   Balance Sortie 2017     99227 non-null  object
#  14   Balance Sortie 2016     99227 non-null  object
#  15   Balance Sortie 2015     99227 non-null  object
#  16   Balance Sortie 2014     99227 non-null  object
#  17   Balance Sortie 2013     99227 non-null  object
#  18   Balance Sortie 2012     99227 non-null  object
# dtypes: int64(1), object(18)
# memory usage: 14.4+ MB

# %% [markdown]
# **On remarque 2 choses selon les infos de notre data frame.**
#
#
# *   Les "-" dans le fichier ne sont pas considérés comme étant des éléments nulls
# *   Mise à part le numéro de compte, même les balances de sorties sont comptés comme étant des "object" et non des flottants
